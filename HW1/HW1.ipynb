# %% [markdown]
# Домашняя работа #1
#
# 1. ![HW1_1.JPG](attachment:HW1_1.JPG)
#
# 2. https://github.com/NikolaevAlexey/PYDA_HW
#
# 3. ![HW1_3_18.JPG](attachment:HW1_3_18.JPG)![HW1_3_28.JPG](attachment:HW1_3_28.JPG)
