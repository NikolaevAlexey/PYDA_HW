# %% [markdown]
# Задание 1. Даны 2 строки: long_phrase и short_phrase. Напишите код, который проверяет действительно ли длинная фраза long_phrase длиннее короткой short_phrase. И выводит True или False в зависимости от результата сравнения.

# %%
long_phrase = "Насколько проще было бы писать программы, если бы не заказчики"
short_phrase = "640Кб должно хватить для любых задач. Билл Гейтс (по легенде)"
if len(long_phrase) > len(short_phrase): 
    print("True")
else: print("False")
print("Конец программы")
# Out:
# True
# Конец программы

# %% [markdown]
# Задание 2. Дано значение объема файла в байтах (в мегабайте 2^20 байт). Напишите перевод этого значения в мегабайты в формате: "Объем файла равен 213.68Mb".

# %%
file_volume = int(input("Введите размер = "))
file_volume = file_volume/2**20
print("Объем файла равен ",file_volume,"Mb")
# Out:
# Введите размер = 1048576
# Объем файла равен  1.0 Mb

# %% [markdown]
# Задание 3. Разработать приложение для определения знака зодиака по дате рождения. Пример:
# Введите месяц: март
# Введите число: 6
# Вывод: Рыбы

# %%
month = input("Введите месяц: ")
day = int(input("Введите число: "))
if (month != "январь") & (month != "Январь") & (month != "февраль") & (month != "Февраль") & (month != "март") & \
(month != "Март") & (month != "апрель") & (month != "Апрель") & (month1 != "май") & (month != "Май") & (month != "июнь") & \
(month != "Июнь") & (month != "август") & (month != "Август") & (month != "сентябрь") & (month != "Cентябрь") &\
(month != "октябрь") & (month != "Октябрь") & (month != "ноябрь") & (month != "Ноябрь") & (month != "декабрь") &\
(month != "Декабрь"):
    print("Нет такого месяца. ", month)
elif 31 < day:
    print("Нет такого числа в месяце. ", day)
else:
    if month == "январь" or month == "Январь":
        if 20 <= day <= 31:
            print("Вывод: Водолей")
        else:
            print("Вывод: Козерог")
    if month == "февраль" or month == "Февраль":
        if 19 <= day <= 29:
            print("Вывод: Рыбы")
        elif 1 <= day <=19:
             print("Вывод: Водолей")
        else:
            print("В феврале нет", day, "дня" )
    if month == "март" or month == "Март":
        if 21 <= day <= 31:
            print("Вывод: Овен")
        else:
            print("Вывод: Рыбы")
    if month == "апрель" or month == "Апрель":
        if 20 <= day <= 30:
            print("Вывод: Телец")
        elif 1 <= day <=19:
            print("Вывод: Овен")
        else:
            print("В апреле нет", day, "дня" )
    if month == "май" or month == "Май":
        if 21 <= day <= 31:
            print("Вывод: Близнецы")
        else:
            print("Вывод: Телец")
    if month == "июнь" or month == "Июнь":
        if 21 <= day <= 30:
            print("Вывод: Рак")
        elif 1 <= day <=20:
            print("Вывод: Близнецы")
        else:
            print("В июне нет", day, "дня" )
    if month == "июль" or month == "Июль":
        if 23 <= day <= 31:
            print("Вывод: Лев")
        else:
            print("Вывод: Рак")
    if month == "август" or month == "Август":
        if 23 <= day <= 31:
            print("Вывод: Дева")
        else:
            print("Вывод: Лев")
    if month == "сентябрь" or month == "Cентябрь":
        if 23 <= day <= 30:
            print("Вывод: Весы")
        elif 1 <= day <=22:
            print("Вывод: Дева")
        else:
            print("В сентябре нет", day, "дня" )
    if month == "октябрь" or month == "Октябрь":
        if 23 <= day <= 31:
            print("Вывод: Скорпион")
        else:
            print("Вывод: Весы")
    if month == "ноябрь" or month == "Ноябрь":
        if 22 <= day <= 30:
            print("Вывод: Стрелец")
        elif 1 <= day <=21:
            print("Вывод: Скорпион")
        else:
            print("В ноябре нет", day, "дня" )
    if month == "декабрь" or month == "Декабрь":
        if 22 <= day <= 31:
            print("Вывод: Козерог")
        else:
            print("Вывод: Стрелец")
            
print("Конец программы")
# Out:
# Введите месяц: март
# Введите число: 6
# Вывод: Рыбы
# Конец программы

# %% [markdown]
# Задание 4. Нужно разработать приложение для финансового планирования. Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию. Пользователь вводит:
# заработанную плату в месяц.
# сколько процентов от ЗП уходит на ипотеку.
# сколько процентов от ЗП уходит "на жизнь".
# сколько раз приходит премия в год.
# Остальная часть заработанной платы откладывается на пенсию.
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
# Программа должна учитывать сколько премий было в год.
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
# Пример:
# Введите заработанную плату в месяц: 100000
# Введите сколько процентов уходит на ипотеку: 30
# Введите сколько процентов уходит на жизнь: 50
# Введите количество премий за год: 2
# Вывод: На ипотеку было потрачено: 360000 рублей Было накоплено: 340000 рублей

# %%
pay_month = int(input("Введите заработанную плату в месяц: "))
mortgage_percent = int(input("Введите сколько процентов уходит на ипотеку: "))
life_percent = int(input("Введите сколько процентов уходит на жизнь: "))
bonus_quantity = int(input("Введите количество премий: "))
if mortgage_percent+life_percent>100:
    print("Количество %% не может быть больше 100")
pay_mortgage=pay_month/100*mortgage_percent*12
pay_life=pay_month/100*life_percent*12
pay_bonus=bonus_quantity*pay_month
accumulated=12*pay_month+pay_bonus*0.5-pay_life-pay_mortgage

print("Вывод: На ипотеку было потрачено:",pay_mortgage," рублей. Было накоплено: ",accumulated)
# Out:
# Введите заработанную плату в месяц: 100000
# Введите сколько процентов уходит на ипотеку: 30
# Введите сколько процентов уходит на жизнь: 50
# Введите количество премий: 2
# Вывод: На ипотеку было потрачено: 360000.0  рублей. Было накоплено:  340000.0
